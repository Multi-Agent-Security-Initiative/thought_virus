# %% [markdown]
# This is an example run to show to configure each run.

# %% [markdown]
# Don't refer to this run's files in particular. Just use the `run_folder` variable from `run_config`.
#
# Example:

# %%
from run_config import run_folder

print(f"Run folder is: {run_folder}")
# Out:
# Run folder is: /Users/m/Downloads/SOAR/thought_virus/runs/1

# %% [markdown]
# This way, you can copy/paste this run, make some changes to the input, make some changes the the code, or something else, and everything will just work.

# %% [markdown]
# You can refer to past runs, but try not to refer to future runs. If you need to refer to future runs, copy/paste the entire run

# %%
from run_config import run_folder

print(f"{run_folder}/../0/input/data.csv")
# Out:
# /Users/m/Downloads/SOAR/thought_virus/runs/1/../0/input/data.csv
